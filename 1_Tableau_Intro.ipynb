# %% [markdown]
# #### Tableau
# - Introduction
# - Basic Data Visualization - Summary Tables, Bar Chart, Pie Chart, Scatterplot, bubble chart etc.
# - Advance Data Viz- Dual Axis Chart, Customizing colours /labels/shapes etc.
# - Data Management - Filters, Grouping, Hierarchies, Alias etc.
# - Calculation - Formulas, Quick Table Calculations, Level Of Details(LOD) Calculations etc.
# - Working with multiple data source - Joining, Blending etc.
# - Advance Features - Parameters, Sets, Context Filters, Actions.
# - Predictive Modelling- Regression/Time Series.
# - Sharing your work - Dashboard, Stories, Tableau Server, User Security, Scheduling etc.

# %% [markdown]
# #### Business Intelligence
# - it is process of converting the raw data(unstrcutured data) into meaningful information(structured data)
# - A set of process, Architecture and technologies that drives profitable business actions
#
# - BI is a methods of collecting, storing and analysing data from business operations or activities to optimize performance
# - BI has a direct impact on organizational strategic and operational business decision. it impacts the revenue and financial model of the business

# %% [markdown]
# #### Methodologies & Tools
# - Data Visualization
# - Data Mining
# - Reporting
# - Time Series Analysis
# - on-line Analytical Processing(OLAP)
# - statistical Analysis

# %% [markdown]
# #### Why Visualizations
# 3 Simple Reasons Why You Should First Visualize Data Before Doing Anything Else
#
# - <b>Understand the Missingness Pattern</b> - Real-world data have the missingness problem for various reasons. Subjects refuse to answer specific questions due to privacy concerns like race and income. Subjects accidentally enter the incorrect data (e.g., missing a digit in the phone number).
#
# - <b>Identify Outliers </b>- One early step in data pre-processing is to handle outliers, which are data values that are distinctly different from other data values in the dataset. They can happen at least for two reasons. First, the data are entered by mistake. For example, missing a decimal can make the value 100 times larger (10.24 vs. 1024).
#
# - <b>Generate Meaningful Hypotheses</b> - As machine learning setting, it's always necessary to form
# some hypotheses and develop some meaningful models with the training dataset, which we hope hold when we run the models in the test dataset. Similar to the identification of outliers, specific data structures of given datasets will determine how we visualize the data before doing any testing. For example, if you're trying to identify a possible linear relationship between two continuous variables, you can start with the scatter plots, as shown in the last section.

# %% [markdown]
# #### Why Tableau?
# - First ultimate skill for Data Science
# - User Friendly
# - Apply to any Business
# - Fast and Easy
# - Even with Excel, Tableau will be your best partner
# - No Coding Skills Required
# - Community is Huge
# - Leverage the Power of Data
# - Makes easy to make your data reports to explain

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t1.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t2.png")

# %% [markdown]
# - use demographic details dataset
# - show total population
# - average literacy rate
# - allow drill down the states by cities

# %% [markdown]
# #### Future impact of BI
# - Collaborative Business Intelligence - Facilitating team work
# - Increasingly Integrated BI Systems - Third party systems will be increasingly intertwined with Bl, simplifying data processing.
# - Machine Learning - Al analyzes past data to provide insight and forecasting.
# - Data "Proactivity" - Will respond automatically to inquires and bring relevant data to users
# - Network Advancements - Tech infrastructure will expand to store large amount of data to support Bl systems.
# - Data Driven Culture - Adopting data driven culture by giving all employee to incorporate Bl into everyday process.

# %% [markdown]
# - Tableau installation : https://www.tableau.com/products/desktop
# - Trick : https://www.tableau.com/support/releases
#     - Resources --> support  --> all releases
# - datasets : https://www.tableau.com/learn/articles/free-public-data-sets

# %% [markdown]
# #### Visual Segment
#
# - Comparison(bar graph)
# - Composition(pie chart, donut chart)
# - Distribution(histogram)
# - Trend(line chart)
# - Maps
# - Relation (relation between quantity and sales scatter plot)

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t3.png")

# %% [markdown]
# - tableau reader : https://www.tableau.com/products/reader
# - tableau public : https://public.tableau.com/app/discover

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t4.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t5.png")

# %% [markdown]
# #### Tableau Desktop
# - Data Visualization Intro
# - Visual Analytics
# - Visual Analytics - 1
# - Visual Analytics - 2
# - Calculation
# - LOD Problem Set
# - Dashboard and Stories
# - Advance Operations
# - Advance Analysis
# - Advance Analysis & Conclusion

# %% [markdown]
# #### Tableau Introduction
# - Tableau - Introduction
# - Why Tableau?
# - Importing Data
# - Understanding Tableau Interface
# - Live vs Extract
# - Measures vs Dimensions
# - Understanding Shelves, Pills, Summary Tables
# - Creating Basic Chart
# - Changing Aggregations
# - Changing Format
# - Saving your work

# %% [markdown]
# #### importing data
# - click on home icon --> To a file, To a Server, Saved Data Sources
# - click on text file --> select the file

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t11.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t6.png")

# %% [markdown]
# #### There are two types of connection
# - live : it is used for linking with your data(to connect hadoop, data size is huge)
# - extract : copy data to local in a tableau supported format i.e tableau data extraxt(.tde).(when we have a connection is slow, size is 10MB)
#
# #### Data Pane
# - dimensions : The columns on which we are not going to perform operations. we use this as reference are called dimensions
# - measures : The columns in our dataset on which we are going to perform mathematical operations are called measures

# %% [markdown]
# Tableau creates some default dimensions and measures like
# - Measure Names(Dimensions)
# - Latitude(Measures)
# - Longitude(Measures)
# - Number of Records(Measures)

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t12.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t7.png")

# %% [markdown]
# #### ways of creating the summary table
# - drag and drop
# - point and click(recommended)
# - double click

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t13.png")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t14.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t15.png")

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t8.png")

# %% [markdown]
# - dimensions to rows and measures to columns is called Pills

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t9.png")

# %% [markdown]
# #### default formats

# %%
from IPython.display import Image
Image("E:/code/12.BITools/img/t10.png")
